# %%
import pandas as pd
import numpy as np

# %%
base_train = pd.read_csv('data/Base_Train/train_df.csv')
base_train
# Out:
#            text_id                                          full_text  \
# 0     0016926B079C  I think that students would benefit from learn...
# 1     0022683E9EA5  When a problem is a change you have to let it ...
# 2     00299B378633  Dear, Principal[PARAGRAPH] If u change the sch...
# 3     003885A45F42  The best time in life is when you become yours...
# 4     0049B1DF5CCC  Small act of kindness can impact in other peop...
# ...            ...                                                ...
# 3906  FFD29828A873  I believe using cellphones in class for educat...
# 3907  FFD9A83B0849  Working alone, students do not have to argue w...
# 3908  FFDC4011AC9C  "A problem is a chance for you to do your best...
# 3909  FFE16D704B16  Many people disagree with Albert Schweitzer's ...
# 3910  FFED00D6E0BD  Do you think that failure is the main thing fo...
#
#       cohesion  syntax  vocabulary  phraseology  grammar  conventions  fold
# 0          3.5     3.5         3.0          3.0      4.0          3.0     1
# 1          2.5     2.5         3.0          2.0      2.0          2.5     0
# 2          3.0     3.5         3.0          3.0      3.0          2.5     4
# 3          4.5     4.5         4.5          4.5      4.0          5.0     3
# 4          2.5     3.0         3.0          3.0      2.5          2.5     1
# ...        ...     ...         ...          ...      ...          ...   ...
# 3906       2.5     3.0         3.0          3.5      2.5          2.5     3
# 3907       4.0     4.0         4.0          4.0      3.5          3.0     1
# 3908       2.5     3.0         3.0          3.0      3.5          3.0     3
# 3909       4.0     4.5         4.5          4.0      4.5          4.5     3
# 3910       3.5     2.5         3.5          3.0      3.0          3.5     4
#
# [3911 rows x 9 columns]

# %%
fold_list = []
for i in range(5):
    tmp_train = base_train[base_train['fold'] == i]
    fold_list.append(tmp_train.iloc[:, 2:8].mean())
fold_list
# Out:
# [cohesion       3.077366
#  syntax         2.971867
#  vocabulary     3.205243
#  phraseology    3.065857
#  grammar        2.959719
#  conventions    3.035166
#  dtype: float64,
#  cohesion       3.125160
#  syntax         3.007024
#  vocabulary     3.226054
#  phraseology    3.111111
#  grammar        3.015964
#  conventions    3.079183
#  dtype: float64,
#  cohesion       3.140665
#  syntax         3.068414
#  vocabulary     3.258312
#  phraseology    3.138747
#  grammar        3.069693
#  conventions    3.116368
#  dtype: float64,
#  cohesion       3.131074
#  syntax         3.048593
#  vocabulary     3.245524
#  phraseology    3.125959
#  grammar        3.042839
#  conventions    3.074169
#  dtype: float64,
#  cohesion       3.161125
#  syntax         3.045396
#  vocabulary     3.243606
#  phraseology    3.142583
#  grammar        3.076087
#  conventions    3.100384
#  dtype: float64]

# %%
base_train.columns[2:8]
# Out:
# Index(['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar',
#        'conventions'],
#       dtype='object')
